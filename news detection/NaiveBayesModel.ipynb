# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\chigerwe\appdata\local\programs\python\python310\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\chigerwe\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: tqdm in c:\users\chigerwe\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in c:\users\chigerwe\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\chigerwe\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2022.9.13)
# Requirement already satisfied: colorama in c:\users\chigerwe\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.5)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
truenews = pd.read_csv('True.csv')
fakenews = pd.read_csv('Fake.csv')

# %%
fakenews.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
truenews.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fakenews.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date
# count          23481
# unique          1681
# top     May 10, 2017
# freq              46

# %%
truenews.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
truenews['True/Fake']='True'
fakenews['True/Fake']='Fake'

# %%
# Combine the 2 DataFrames into a single data frame
news = pd.concat([truenews, fakenews])
news["Article"] = news["title"] + news["text"]
news.sample(frac = 1) #Shuffle 100%
# Out:
#                                                    title  \
# 18255  FORMER DEMOCRAT WHO VOTED FOR TRUMP RIPS DEMOC...
# 1321    Trump’s Son Gets Schooled After Claiming Cons...
# 1674    Scott Baio Gets His A** Handed To Him By Erin...
# 13086  ‘NAFTA BOY’ BILL CLINTON HECKLED At Detroit La...
# 10060  Republican Cruz crushes Trump in Wisconsin, sa...
# ...                                                  ...
# 9149   Democrats link guns to terrorism, turn to gun ...
# 8434    ‘Christians’ Who Leave Fake $20 Tips For Serv...
# 4747    President Obama Warns Putin: Don’t Hack Our E...
# 12415  WOW! SCRUBBED 1998 GEORGE SOROS Video Resurfac...
# 4122   Trump's 'big announcement' on tax to be broad ...
#
#                                                     text       subject  \
# 18255  After a Fox Business interview earlier in the ...     left-news
# 1321   A comedian went too far today and for that, sh...          News
# 1674   Erin Moran s family just declared war on Scott...          News
# 13086                                                         politics
# 10060  MILWAUKEE (Reuters) - Republican Ted Cruz easi...  politicsNews
# ...                                                  ...           ...
# 9149   WASHINGTON (Reuters) - President Barack Obama ...  politicsNews
# 8434   Christian fundamentalists picked on the wrong ...          News
# 4747   Recently, intelligence agencies, including the...          News
# 12415  Knowing there were problems ahead for the Jews...      politics
# 4122   WASHINGTON (Reuters) - President Donald Trump’...  politicsNews
#
#                     date True/Fake  \
# 18255       Jul 26, 2017      Fake
# 1321        May 30, 2017      Fake
# 1674      April 26, 2017      Fake
# 13086        Sep 5, 2016      Fake
# 10060     April 5, 2016       True
# ...                  ...       ...
# 9149      June 13, 2016       True
# 8434    January 30, 2016      Fake
# 4747   September 6, 2016      Fake
# 12415       Nov 12, 2016      Fake
# 4122     April 22, 2017       True
#
#                                                  Article
# 18255  FORMER DEMOCRAT WHO VOTED FOR TRUMP RIPS DEMOC...
# 1321    Trump’s Son Gets Schooled After Claiming Cons...
# 1674    Scott Baio Gets His A** Handed To Him By Erin...
# 13086  ‘NAFTA BOY’ BILL CLINTON HECKLED At Detroit La...
# 10060  Republican Cruz crushes Trump in Wisconsin, sa...
# ...                                                  ...
# 9149   Democrats link guns to terrorism, turn to gun ...
# 8434    ‘Christians’ Who Leave Fake $20 Tips For Serv...
# 4747    President Obama Warns Putin: Don’t Hack Our E...
# 12415  WOW! SCRUBBED 1998 GEORGE SOROS Video Resurfac...
# 4122   Trump's 'big announcement' on tax to be broad ...
#
# [44898 rows x 6 columns]

# %% [markdown]
# #Data Cleaning

# %%
from nltk.corpus import stopwords
import string
import nltk
#nltk.download()

# %%
def process_text(s):

    # Check string to see if they are a punctuation
    nopunc = [char for char in s if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Convert string to lowercase and remove stopwords
    clean_string = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return clean_string

# %%
# Tokenize the Article
#rerun, takes LOOOONG
news['Clean Text'] = news['Article'].apply(process_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 3
#       1 # Tokenize the Article
#       2 #rerun, takes LOOOONG
# ----> 3 news['Clean Text'] = news['Article'].apply(process_text)
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In [11], line 10, in process_text(s)
#       7 nopunc = ''.join(nopunc)
#       9 # Convert string to lowercase and remove stopwords
# ---> 10 clean_string = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
#      11 return clean_string
#
# Cell In [11], line 10, in <listcomp>(.0)
#       7 nopunc = ''.join(nopunc)
#       9 # Convert string to lowercase and remove stopwords
# ---> 10 clean_string = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
#      11 return clean_string
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\reader\wordlist.py:21, in WordListCorpusReader.words(self, fileids, ignore_lines_startswith)
#      18 def words(self, fileids=None, ignore_lines_startswith="\n"):
#      19     return [
#      20         line
# ---> 21         for line in line_tokenize(self.raw(fileids))
#      22         if not line.startswith(ignore_lines_startswith)
#      23     ]
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\reader\api.py:218, in CorpusReader.raw(self, fileids)
#     216 contents = []
#     217 for f in fileids:
# --> 218     with self.open(f) as fp:
#     219         contents.append(fp.read())
#     220 return concat(contents)
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\reader\api.py:231, in CorpusReader.open(self, file)
#     223 """
#     224 Return an open stream that can be used to read the given file.
#     225 If the file's encoding is not None, then the stream will
#    (...)
#     228 :param file: The file identifier of the file to read.
#     229 """
#     230 encoding = self.encoding(file)
# --> 231 stream = self._root.join(file).open(encoding)
#     232 return stream
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\data.py:334, in FileSystemPathPointer.join(self, fileid)
#     332 def join(self, fileid):
#     333     _path = os.path.join(self._path, fileid)
# --> 334     return FileSystemPathPointer(_path)
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\compat.py:41, in py3_data.<locals>._decorator(*args, **kwargs)
#      39 def _decorator(*args, **kwargs):
#      40     args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41     return init_func(*args, **kwargs)
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\data.py:311, in FileSystemPathPointer.__init__(self, _path)
#     304 """
#     305 Create a new path pointer for the given absolute path.
#     306
#     307 :raise IOError: If the given path does not exist.
#     308 """
#     310 _path = os.path.abspath(_path)
# --> 311 if not os.path.exists(_path):
#     312     raise OSError("No such file or directory: %r" % _path)
#     313 self._path = _path
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %%
news.sample(5)
# Out:
#                                                    title  \
# 17805  Cambodia's Hun Sen renews criticism of United ...
# 17676  No visas, bad jobs: Venezuelan emigrants reluc...
# 6911   Trump clear on China's stance on call with Tai...
# 13267  Chinese police detain 11 over deadly Tianjin s...
# 17602  LOL! PRESIDENT TRUMP Wants Network Who Pushes ...
#
#                                                     text       subject  \
# 17805  PHNOM PENH (Reuters) - Cambodian Prime Ministe...     worldnews
# 17676  CARACAS/SAN CRISTOBAL, Venezuela (Reuters) - E...     worldnews
# 6911   BEIJING (Reuters) - China said on Monday U.S. ...  politicsNews
# 13267  BEIJING (Reuters) - Chinese police have detain...     worldnews
# 17602  Earlier today, President Trump tweeted:  We sh...     left-news
#
#                     date True/Fake  \
# 17805  October 11, 2017       True
# 17676  October 12, 2017       True
# 6911   December 5, 2016       True
# 13267  December 3, 2017       True
# 17602       Nov 27, 2017      Fake
#
#                                                  Article
# 17805  Cambodia's Hun Sen renews criticism of United ...
# 17676  No visas, bad jobs: Venezuelan emigrants reluc...
# 6911   Trump clear on China's stance on call with Tai...
# 13267  Chinese police detain 11 over deadly Tianjin s...
# 17602  LOL! PRESIDENT TRUMP Wants Network Who Pushes ...

# %%
#!pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.3-cp310-cp310-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 2.3 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\chigerwe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.23.4)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
#      ---------------------------------------- 40.1/40.1 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.0.0 in c:\users\chigerwe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.2.0)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.1.3 scipy-1.9.3 threadpoolctl-3.1.0
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=process_text).fit(news['Clean Text'])

print(len(bow_transformer.vocabulary_)) #Total vocab words
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Clean Text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 bow_transformer = CountVectorizer(analyzer=process_text).fit(news['Clean Text'])
#       3 print(len(bow_transformer.vocabulary_))
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File c:\Users\Chigerwe\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Clean Text'

# %%
#Bag-of-Words (bow) transform the entire DataFrame of text
news_bow = bow_transformer.transform(news['Clean Text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 2
#       1 #Bag-of-Words (bow) transform the entire DataFrame of text
# ----> 2 news_bow = bow_transformer.transform(news['Clean Text'])
#
# NameError: name 'bow_transformer' is not defined
